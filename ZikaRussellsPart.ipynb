# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('cdc_zika.csv')
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   report_date                location location_type  \
# 0  2016-03-19  Argentina-Buenos_Aires      province
# 1  2016-03-19  Argentina-Buenos_Aires      province
# 2  2016-03-19  Argentina-Buenos_Aires      province
# 3  2016-03-19  Argentina-Buenos_Aires      province
# 4  2016-03-19  Argentina-Buenos_Aires      province
#
#                             data_field data_field_code  time_period  \
# 0     cumulative_confirmed_local_cases          AR0001          NaN
# 1      cumulative_probable_local_cases          AR0002          NaN
# 2  cumulative_confirmed_imported_cases          AR0003          NaN
# 3   cumulative_probable_imported_cases          AR0004          NaN
# 4         cumulative_cases_under_study          AR0005          NaN
#
#    time_period_type value   unit
# 0               NaN     0  cases
# 1               NaN     0  cases
# 2               NaN     2  cases
# 3               NaN     1  cases
# 4               NaN   127  cases

# %%
russellssection = df[:99706]
country_data = russellssection[russellssection['location_type'] == 'country']
country_data[country_data.data_field_code == 'DO0001']
# Out:
#       report_date            location location_type                data_field  \
# 93194  2016-01-09  Dominican_Republic       country  total_zika_new_suspected
# 93195  2016-01-16  Dominican_Republic       country  total_zika_new_suspected
# 93196  2016-01-23  Dominican_Republic       country  total_zika_new_suspected
# 93198  2016-01-30  Dominican_Republic       country  total_zika_new_suspected
# 93203  2016-02-06  Dominican_Republic       country  total_zika_new_suspected
# 93213  2016-02-13  Dominican_Republic       country  total_zika_new_suspected
# 93226  2016-02-20  Dominican_Republic       country  total_zika_new_suspected
# 93237  2016-02-27  Dominican_Republic       country  total_zika_new_suspected
# 93244  2016-03-05  Dominican_Republic       country  total_zika_new_suspected
# 93256  2016-03-12  Dominican_Republic       country  total_zika_new_suspected
# 93281  2016-03-19  Dominican_Republic       country  total_zika_new_suspected
# ...

# %%
ecuador = country_data[(country_data.location == 'Ecuador')&(country_data.data_field_code == 'EC0002')]
ecuador
# Out:
#       report_date location location_type                       data_field  \
# 98924  2016-03-30  Ecuador       country  total_zika_confirmed_cumulative
# 98990  2016-04-06  Ecuador       country  total_zika_confirmed_cumulative
# 99058  2016-04-13  Ecuador       country  total_zika_confirmed_cumulative
# 99122  2016-04-20  Ecuador       country  total_zika_confirmed_cumulative
# 99189  2016-04-27  Ecuador       country  total_zika_confirmed_cumulative
# 99260  2016-05-04  Ecuador       country  total_zika_confirmed_cumulative
# 99328  2016-05-18  Ecuador       country  total_zika_confirmed_cumulative
# 99396  2016-05-25  Ecuador       country  total_zika_confirmed_cumulative
# 99466  2016-06-01  Ecuador       country  total_zika_confirmed_cumulative
# 99522  2016-06-15  Ecuador       country  total_zika_confirmed_cumulative
# 99582  2016-06-22  Ecuador       country  total_zika_confirmed_cumulative
# 99644  2016-06-29  Ecuador       country  total_zika_confirmed_cumulative
#
# ...

# %%
k = ['AR0001','AR0002','AR0003','AR0004','AR0005','AR0006',]

for j in k:
    argentina = russellssection[(russellssection['data_field_code'] == j)]
    print argentina.data_field.unique()[0]
    cum_sums = []
    dates = argentina.report_date.unique()
    for date in argentina.report_date.unique():
        cum_sum = sum(argentina[argentina.report_date == date].value.astype(int))
        cum_sums.append(cum_sum)
    cum_sums = np.array(cum_sums)
    for i,n in zip(cum_sums,dates):
        print n,' ',i
    print
# Out:
# cumulative_confirmed_local_cases
# 2016-03-19   1
# 2016-03-26   1
# 2016-04-02   1
# 2016-04-09   1
# 2016-04-16   1
# 2016-04-29   1
# 2016-05-07   100
# 2016-05-14   3
# 2016-05-22   102
# 2016-05-30   19
# 2016-06-06   21
# 2016-06-13   21
# 2016-06-18   21
# 2016-06-26   23
#
# cumulative_probable_local_cases
# 2016-03-19   0
# 2016-03-26   0
# 2016-04-02   0
# 2016-04-09   0
# 2016-04-16   0
# 2016-04-29   0
# 2016-05-07   7
# 2016-05-14   0
# 2016-05-22   7
# 2016-05-30   3
# 2016-06-06   5
# 2016-06-13   6
# 2016-06-18   6
# 2016-06-26   9
#
# cumulative_confirmed_imported_cases
# 2016-03-19   16
# 2016-03-26   17
# 2016-04-02   17
# 2016-04-09   17
# 2016-04-16   17
# 2016-04-29   17
# 2016-05-07   73
# 2016-05-14   17
# 2016-05-22   73
# 2016-05-30   17
# 2016-06-06   17
# 2016-06-13   17
# 2016-06-18   17
# 2016-06-26   17
#
# cumulative_probable_imported_cases
# 2016-03-19   2
# 2016-03-26   1
# 2016-04-02   1
# 2016-04-09   1
# 2016-04-16   1
# 2016-04-29   1
# ...

# %%
brazil = russellssection[russellssection.data_field_code == 'BR0011']
brazil_region = brazil[brazil.location_type == 'region']
brazil_state = brazil[brazil.location_type == 'state']

# %%
brazil_region.location.unique()
# Out:
# array(['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'], dtype=object)

# %%
brazil_state.location.unique()
# Out:
# array(['Brazil-Rondonia', 'Brazil-Acre', 'Brazil-Amazonas',
#        'Brazil-Roraima', 'Brazil-Para', 'Brazil-Amapa', 'Brazil-Tocantins',
#        'Brazil-Maranhao', 'Brazil-Piaui', 'Brazil-Ceara',
#        'Brazil-Rio_Grande_do_Norte', 'Brazil-Paraiba', 'Brazil-Pernambuco',
#        'Brazil-Alagoas', 'Brazil-Sergipe', 'Brazil-Bahia',
#        'Brazil-Minas_Gerais', 'Brazil-Espirito_Santo',
#        'Brazil-Rio_de_Janeiro', 'Brazil-Sao_Paulo', 'Brazil-Parana',
#        'Brazil-Santa_Catarina', 'Brazil-Rio_Grande_do_Sul',
#        'Brazil-Mato_Grosso_do_Sul', 'Brazil-Mato_Grosso', 'Brazil-Goias',
#        'Brazil-Distrito_Federal', 'Brazil'], dtype=object)

# %%
p = [brazil_region,brazil_state]
b = np.zeros((2,7))

for x in range(len(p)):
    cum_sums = []
    dates = p[x].report_date.unique()
    for date in dates:
        cum_sum = sum(p[x][p[x].report_date == date].value.astype(int))
        cum_sums.append(cum_sum)
    cum_sums = np.array(cum_sums)
    
    for i,n in zip(cum_sums,dates):
        print n,' ',i
    b[x] = cum_sums
    print 
# plt.fig()
# plt.plot(range(7),)
# Out:
# 2016-04-02   91387
# 2016-04-23   120161
# 2016-04-30   127822
# 2016-05-07   138108
# 2016-05-14   138108
# 2016-05-21   148905
# 2016-05-28   161241
#
# 2016-04-02   182774
# 2016-04-23   240322
# 2016-04-30   255644
# 2016-05-07   276216
# 2016-05-14   276216
# 2016-05-21   297810
# 2016-05-28   322482

# %%
b
# Out:
# array([[  91387.,  120161.,  127822.,  138108.,  138108.,  148905.,
#          161241.],
#        [ 182774.,  240322.,  255644.,  276216.,  276216.,  297810.,
#          322482.]])

# %% [markdown]
# **This one is right - the other one double counted**

# %%
brazil_total = b[0] 
brazil_total
# Out:
# array([  91387.,  120161.,  127822.,  138108.,  138108.,  148905.,  161241.])

# %%
plt.figure()
plt.plot(range(7),b[0])
plt.title('Cases of Zika in Brazil')
labels = dates
plt.xticks(range(7), labels, rotation='vertical')
plt.show()

# %%
colombia = russellssection[russellssection.data_field_code == 'CO0003']
colombia
# Out:
#       report_date                                 location location_type  \
# 8658   2016-01-09               Colombia-Antioquia-Unknown  municipality
# 8659   2016-01-09              Colombia-Antioquia-Medellin  municipality
# 8660   2016-01-09             Colombia-Antioquia-Abejorral  municipality
# 8661   2016-01-09              Colombia-Antioquia-Abriaqui  municipality
# 8662   2016-01-09            Colombia-Antioquia-Alejandria  municipality
# 8663   2016-01-09                 Colombia-Antioquia-Amaga  municipality
# 8664   2016-01-09                Colombia-Antioquia-Amalfi  municipality
# 8665   2016-01-09                 Colombia-Antioquia-Andes  municipality
# 8666   2016-01-09           Colombia-Antioquia-Angelopolis  municipality
# 8667   2016-01-09             Colombia-Antioquia-Angostura  municipality
# 8668   2016-01-09                 Colombia-Antioquia-Anori  municipality
# 8669   2016-01-09  Colombia-Antioquia-Santafe_De_Antioquia  municipality
# ...

# %%
cum_sums = []
dates = colombia.report_date.unique()
for date in dates:
    cum_sum = sum(colombia[colombia.report_date == date].value.astype(int))
    cum_sums.append(cum_sum)
cum_sums = np.array(cum_sums)
    
for i,n in zip(cum_sums,dates):
    print n,' ',i

plt.figure()
plt.plot(range(len(cum_sums)),cum_sums)
plt.title('Cases of Zika in Colombia')
labels = dates
plt.xticks(range(len(cum_sums)), labels, rotation='vertical')
plt.show()
# Out:
# 2016-01-09   1911
# 2016-01-16   2599
# 2016-01-23   2117
# 2016-01-30   3007
# 2016-02-06   4065
# 2016-02-13   5210
# 2016-02-20   6583
# 2016-02-27   5706
# 2016-03-05   6533
# 2016-03-12   6749
# 2016-03-19   7201
# 2016-03-26   7117
# 2016-04-02   5978
# 2016-04-09   5729
# 2016-04-16   5991
# 2016-04-23   5400
# 2016-04-30   5627
# 2016-05-07   4558
# 2016-05-14   3427
# 2016-05-21   3609
# 2016-05-28   3384
# 2016-06-04   3388
# 2016-06-11   3639
# 2016-06-18   3343
# 2016-06-25   3410

# %%
for i in colombia.location.unique():
    print i
# Out:
# Colombia-Antioquia-Unknown
# Colombia-Antioquia-Medellin
# Colombia-Antioquia-Abejorral
# Colombia-Antioquia-Abriaqui
# Colombia-Antioquia-Alejandria
# Colombia-Antioquia-Amaga
# Colombia-Antioquia-Amalfi
# Colombia-Antioquia-Andes
# Colombia-Antioquia-Angelopolis
# Colombia-Antioquia-Angostura
# Colombia-Antioquia-Anori
# Colombia-Antioquia-Santafe_De_Antioquia
# Colombia-Antioquia-Anza
# Colombia-Antioquia-Apartado
# Colombia-Antioquia-Arboletes
# Colombia-Antioquia-Argelia
# Colombia-Antioquia-Armenia
# Colombia-Antioquia-Barbosa
# Colombia-Antioquia-Belmira
# Colombia-Antioquia-Bello
# Colombia-Antioquia-Betania
# Colombia-Antioquia-Betulia
# Colombia-Antioquia-Ciudad_Bolivar
# Colombia-Antioquia-Briceno
# Colombia-Antioquia-Buritica
# Colombia-Antioquia-Caceres
# Colombia-Antioquia-Caicedo
# Colombia-Antioquia-Caldas
# Colombia-Antioquia-Campamento
# Colombia-Antioquia-Canasgordas
# Colombia-Antioquia-Caracoli
# Colombia-Antioquia-Caramanta
# Colombia-Antioquia-Carepa
# ...
